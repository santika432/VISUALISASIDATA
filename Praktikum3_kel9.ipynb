# %% [markdown]
# <a href="https://colab.research.google.com/github/santika432/VISUALISASIDATA/blob/main/Praktikum3_kel9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###**Praktikum3 : Matplotlip-line plot**
# **Kelompokn 9 :**
#
#
# *   Santika Sintia Larasati -0110122045
# *   List item

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **Dataset**

# %%
#buat data sample
months =['jan','feb','mar','apr','mei','jun','jul','agst','sep','okt','nov','dec']
product_A_sales = [10,20,15,25,30,45,40,50,60,55,65,70]
product_B_sales = [5,10,8,30,33,25,56,10,11,48,20,21]

# %% [markdown]
# ***Single Line Plot***

# %%
#line plot 1 garis, style grafik default
plt.plot(months ,product_A_sales,label='product A')
plt.title('Penjualan Produk A Per Bulan')
plt.xlabel('Bulan')
plt.ylabel('penjualan')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Multiple Line & Customizations**

# %%
#line plot 1 garis, style grafik default
plt.plot(months , product_A_sales,label='product A',linestyle="--", marker='o')
plt.plot(months , product_B_sales,label='product B', linestyle="-", marker='x')

plt.title('Penjualan Produk Per Bulan')
plt.xlabel('Bulan')
plt.ylabel('penjualan')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Jenis garis untuk menunjukan tren**

# %%
#data sample tambahan
product_C_sales=['18','2','25','28','12','45','48','17','12','10','15','35']
product_D_sales=['10','7','30','2','45','25','23','16','11','9','13','20']
#line plot 1 garis, style grafik default
plt.plot(months , product_A_sales,label='product A',linestyle="--",color='blue')
plt.plot(months , product_B_sales,label='product B', linestyle="-", color='Red')
plt.plot(months , product_C_sales,label='product C', linestyle=":", color='green')
plt.plot(months , product_D_sales,label='product D', linestyle="-.",color='purple')

plt.title('Penjualan Produk Per Bulan')
plt.xlabel('Bulan')
plt.ylabel('jumlah penjualan')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Sub plot pada line chart**

# %%
#subplot, 2 baris 1 kolom , panjang 10 inci, tinnggi 8 inci
fig, axs =plt.subplots(2,1, figsize=(10,8))
#plot pertama untuk  produk c
axs[0].plot(months, product_C_sales, label='Product c', color='green', marker='d')
axs[0].set_title('penjualan product C perbulan')
axs[0].set_xlabel('Bulan')
axs[0].set_ylabel ('jumlah penjualan')
axs[0].legend()
axs[0].grid('true')

axs[1].plot(months, product_D_sales, label='Product D', color='red',marker='s')
axs[1].set_title('penjualan product D perbulan')
axs[1].set_xlabel('Bulan')
axs[1].set_ylabel ('jumlah penjualan')
axs[1].legend()
axs[1].grid('true')
